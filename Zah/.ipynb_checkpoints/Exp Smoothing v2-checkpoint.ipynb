# %% [markdown]
# # Import packages

# %%
# Import packages
import yfinance as yf
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import datetime as dt
import statsmodels.api as sm

from sklearn.model_selection import train_test_split
from statsmodels.tsa.api import ExponentialSmoothing, SimpleExpSmoothing, Holt
from statsmodels.tsa.seasonal import seasonal_decompose

# %% [markdown]
# # Input data

# %%
# Get data
data = yf.download('USDVND=X','2016-01-01','2024-01-01') # from 1 Jan 2021 to 31 December 2022

# Plot
data['Adj Close'].plot()
plt.title("USDxVND from 2016 to YTD")
plt.show()
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %% [markdown]
# # Exponential smoothing

# %%
# Formatting and splitting dataset into train data and test data
df = pd.DataFrame(data, columns=['Adj Close'])
df = df.reset_index()
x = (df.index < len(df)-365)
df_train = df[x].copy()
df_test = df[~x].copy()

# %% [markdown]
# #### Holt's Linear Smoothing
# Use when there is trend in data, and no seasonality

# %%
model = ExponentialSmoothing(df_train['Adj Close'], trend='add', seasonal_periods=12).fit()
df['Pred'] = model.predict(start=df_test.index[0], end = df_test.index[-1])

df.set_index("Date", inplace=True)
df.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# # Evaluate model predicition

# %%
from sklearn.metrics import mean_absolute_error, mean_absolute_percentage_error, mean_squared_error

mae = mean_absolute_error(df_test['Adj Close'], forecast_test)
mape = mean_absolute_percentage_error(df_test['Adj Close'], forecast_test)
rmse = np.sqrt(mean_squared_error(df_test['Adj Close'], forecast_test))

print(f'mae: {mae}')
print(f'mape: {mape}')
print(f'rmse: {rmse}')
# Out:
# mae: 460.1191673180538
# mape: 0.01921528790613592
# rmse: 553.3483140177663
