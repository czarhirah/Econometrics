# %% [markdown]
# # Import packages

# %%
# Import packages
import yfinance as yf
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import plotly.graph_objs as go
import plotly.io as pio
import keras.backend as K
import tensorflow as tf
import keras

from statsmodels.graphics.tsaplots import plot_acf
from statsmodels.graphics.tsaplots import plot_pacf
from statsmodels.graphics.tsaplots import plot_predict

from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.seasonal import seasonal_decompose

from pandas import DataFrame
from pandas_datareader import data as wb
from matplotlib import pyplot

from datetime import datetime

from sklearn.preprocessing import StandardScaler
from sklearn.metrics import r2_score
from keras.models import Sequential
from keras.layers import Dense
from keras.callbacks import EarlyStopping
from tensorflow.keras.callbacks import EarlyStopping
from keras.optimizers import Adam
from keras.layers import LSTM

# %matplotlib inline

# Set figure parameters
plt.rcParams['figure.figsize'] = [10, 7.5]

# %% [markdown]
# # Input data

# %%
yf.pdr_override()

data = wb.get_data_yahoo('VND=x', start = '2014-01-01', end = '2024-12-31', interval = '1mo')

# Plot
data['Adj Close'].plot()
plt.title("USDxVND from 2014 to YTD")
plt.show()

# Summary statistics
df = pd.DataFrame(data['Adj Close']) 

diff = df.index.values[-1] - df.index.values[0]
months = diff.astype('timedelta64[M]')
years = int(months/12)
print("Total data: %d years" %years)
# Out:
# [*********************100%%**********************]  1 of 1 completed
# Total data: 10 years

# %% [markdown]
# # Processing data

# %%
# Seperate into train and test data
to_row = int(len(df)*0.66)

df_train = pd.DataFrame(df[0:to_row]['Adj Close'])
df_test = pd.DataFrame(df[to_row:]['Adj Close'])

# Plot
plt.plot(df[0:to_row]['Adj Close'], 'green', label='Train')
plt.plot(df[to_row:]['Adj Close'],'blue',label='Test')
plt.legend()
plt.show()

# %%
# Data normalisation - rescale data to make mean of observed values 0 

sc = StandardScaler()
train_sc = sc.fit_transform(df_train)
test_sc = sc.fit_transform(df_test)

# %%
# Further segregate train and test data

x_train = train_sc[:-1]
y_train = train_sc[1:]

x_test = test_sc[:-1]
y_test = test_sc[1:]

# %% [markdown]
# # Modelling ANN

# %%
# Create sequential model
K.clear_session()
n_features = x_train.shape[1]
model = Sequential()
model.add(LSTM(100, activation='relu', input_shape=(1,1)))
model.add(Dense(n_features))
model.summary()
# Out:
# WARNING:tensorflow:From C:\Users\User\anaconda3\envs\tensorflow_env\lib\site-packages\keras\src\backend\common\global_state.py:73: The name tf.reset_default_graph is deprecated. Please use tf.compat.v1.reset_default_graph instead.
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[26], line 5
#       3 n_features = x_train.shape[1]
#       4 model = Sequential()
# ----> 5 model.add(LSTM(100, activation='relu', input_shape=(1,1)))
#       6 model.add(Dense(n_features))
#       7 model.summary()
#
# File ~\anaconda3\envs\tensorflow_env\lib\site-packages\keras\src\layers\rnn\lstm.py:459, in LSTM.__init__(self, units, activation, recurrent_activation, use_bias, kernel_initializer, recurrent_initializer, bias_initializer, unit_forget_bias, kernel_regularizer, recurrent_regularizer, bias_regularizer, activity_regularizer, kernel_constraint, recurrent_constraint, bias_constraint, dropout, recurrent_dropout, seed, return_sequences, return_state, go_backwards, stateful, unroll, **kwargs)
#     432 def __init__(
#     433     self,
#     434     units,
#    (...)
#     457     **kwargs,
#     458 ):
# --> 459     cell = LSTMCell(
#     460         units,
#     461         activation=activation,
#     462         recurrent_activation=recurrent_activation,
#     463         use_bias=use_bias,
#     464         kernel_initializer=kernel_initializer,
#     465         unit_forget_bias=unit_forget_bias,
#     466         recurrent_initializer=recurrent_initializer,
#     467         bias_initializer=bias_initializer,
#     468         kernel_regularizer=kernel_regularizer,
#     469         recurrent_regularizer=recurrent_regularizer,
#     470         bias_regularizer=bias_regularizer,
#     471         kernel_constraint=kernel_constraint,
#     472         recurrent_constraint=recurrent_constraint,
#     473         bias_constraint=bias_constraint,
#     474         dropout=dropout,
#     475         recurrent_dropout=recurrent_dropout,
#     476         dtype=kwargs.get("dtype", None),
#     477         trainable=kwargs.get("trainable", True),
#     478         name="lstm_cell",
#     479         seed=seed,
#     480         implementation=kwargs.pop("implementation", 2),
#     481     )
#     482     super().__init__(
#     483         cell,
#     484         return_sequences=return_sequences,
#    (...)
#     490         **kwargs,
#     491     )
#     492     self.input_spec = InputSpec(ndim=3)
#
# File ~\anaconda3\envs\tensorflow_env\lib\site-packages\keras\src\layers\rnn\lstm.py:136, in LSTMCell.__init__(self, units, activation, recurrent_activation, use_bias, kernel_initializer, recurrent_initializer, bias_initializer, unit_forget_bias, kernel_regularizer, recurrent_regularizer, bias_regularizer, kernel_constraint, recurrent_constraint, bias_constraint, dropout, recurrent_dropout, seed, **kwargs)
#     134 self.recurrent_dropout = min(1.0, max(0.0, recurrent_dropout))
#     135 self.seed = seed
# --> 136 self.seed_generator = backend.random.SeedGenerator(seed=seed)
#     138 self.unit_forget_bias = unit_forget_bias
#     139 self.state_size = [self.units, self.units]
#
# File ~\anaconda3\envs\tensorflow_env\lib\site-packages\keras\src\random\seed_generator.py:69, in SeedGenerator.__init__(self, seed, **kwargs)
#      66     dtype = kwargs.get("dtype", None)
#      67     return self.backend.convert_to_tensor([seed, 0], dtype=dtype)
# ---> 69 self.state = self.backend.Variable(
#      70     seed_initializer,
#      71     shape=(2,),
#      72     dtype="uint32",
#      73     trainable=False,
#      74     name="seed_generator_state",
#      75 )
#
# AttributeError: module 'keras.src.backend' has no attribute 'Variable'

# %%
# Compile and fit the model

model.compile(loss=tf.keras.metrics.mean_squared_error, metrics = [tf.keras.RootMeanSquaredError(name='rmse')], optimizer = 'adam')
early_stop = EarlyStopping(monitor = 'loss', patience = 2, verbose = 1)
history = model.fit(x_train, y_train, epochs = 200, batch_size = 1, verbose = 1, callbacks = [early_stop], shuffle = False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 3
#       1 # Compile and fit the model
# ----> 3 model.compile(loss=tf.keras.metrics.mean_squared_error, metrics = [tf.keras.RootMeanSquaredError(name='rmse')], optimizer = 'adam')
#       4 early_stop = EarlyStopping(monitor = 'loss', patience = 2, verbose = 1)
#       5 history = model.fit(x_train, y_train, epochs = 200, batch_size = 1, verbose = 1, callbacks = [early_stop], shuffle = False)
#
# NameError: name 'tf' is not defined
